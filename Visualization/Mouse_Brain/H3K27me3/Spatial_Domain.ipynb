# %% [markdown]
# # Plot the Results of the Mouse Brain Dataset

# %% [markdown]
# ## Packages Loading

# %%
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import scanpy as sc
from sklearn.metrics.cluster import adjusted_rand_score

import sys
sys.path.append(r'../../../../')
from Model.utils import reorder_categories

# %% [markdown]
# ## Results Loading

# %%
slices = ['ATAC', 'H3K4me3', 'H3K27ac', 'H3K27me3']

slice_id = 4    # 1, 2, 3, 4

adata_results = sc.read_h5ad(f'../../../Mouse_Brain_{slices[slice_id-1]}.h5ad')

# %% [markdown]
# ## Plot the Spatial Domain Identifications

# %%
## define the plot parameters
colors_domain = {
    'SpaKnit':      [   '#e07a5f', '#d3edbe', '#d5a376', '#f4a259', '#597b84', '#52b69a', '#a38161', '#e6db9e',
                        '#83c5be', '#ffbb78', '#f9c74f', '#98df8a', '#F19C79'],

    'SpatialGlue':  [   '#e07a5f', '#83c5be', '#d5a376', '#f4a259', '#e6db9e', '#d3edbe', '#ffbb78', '#597b84',
                        '#a38161', '#52b69a', '#98df8a', '#f9c74f', '#F19C79'],

    'MultiVI':      [   '#e6db9e', '#d3edbe', '#d5a376', '#f4a259', '#597b84', '#e07a5f', '#a38161', '#52b69a',
                        '#83c5be', '#ffbb78', '#98df8a', '#f9c74f', '#F19C79'],

    'MultiMAP':     [   '#52b69a', '#ffbb78', '#e6db9e', '#a38161', '#e07a5f', '#597b84', '#83c5be', '#d5a376',
                        '#f9c74f', '#d3edbe', '#f4a259', '#98df8a', '#F19C79'],

    'STAGATE':      [   '#a38161', '#98df8a', '#597b84', '#f9c74f', '#ffbb78', '#e07a5f', '#f4a259', '#d3edbe',
                        '#52b69a', '#e6db9e', '#d5a376', '#83c5be', '#F19C79'],
    
    'SpaGCN':       [   '#e07a5f', '#ffbb78', '#98df8a', '#f4a259', '#52b69a', '#d3edbe', '#e6db9e', '#a38161',
                        '#597b84', '#83c5be', '#d5a376', '#f9c74f', '#F19C79'],  

    'Modality1':    [   '#e07a5f', '#f4a259', '#d3edbe', '#597b84', '#e6db9e', '#d5a376', '#a38161', '#83c5be',
                        '#52b69a', '#f9c74f', '#ffbb78', '#98df8a', '#F19C79'],  

    'Modality2':    [   '#f4a259', '#e07a5f', '#597b84', '#d3edbe', '#83c5be', '#e6db9e', '#52b69a', '#d5a376',
                        '#a38161', '#98df8a', '#ffbb78', '#f9c74f', '#F19C79']
}
font_size = 24

save_path = f'../../Mouse_Brain/{slices[slice_id-1]}/'

result_key = ['SpaKnit', 'SpatialGlue', 'MultiVI', 'MultiMAP', 'STAGATE', 'SpaGCN', 'Modality1', 'Modality2']

# %%
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['font.size'] = font_size

for result in result_key:
    # new_order = new_order_dict[result]
    # reorder_categories(adata_results, result, new_order)

    fig, ax = plt.subplots(1, 1, figsize=(7, 7))
    sc.pl.spatial(adata_results, img_key="hires", color=result, spot_size=1.3, ax=ax, show=False, palette=colors_domain[result])
    ax.invert_yaxis()
    ax.invert_xaxis()
    ax.set_title(f"")
    ax.set_xlabel('')
    ax.set_ylabel('')

    ax.get_legend().remove()

    # Hide axis borders
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Adjust subplot parameters
    plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.tight_layout()

    plt.savefig(f'{result}.png', dpi=500)
    plt.savefig(f'{result}.eps')

    plt.show()
